# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("country_vaccinations.csv")

# %%
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %% [markdown]
# ## Adding year column in the dataset

# %%
year=[]
lst = list(df['date'])
for i in range(len(lst)):
    year.append(lst[i].split('-')[0])
df['Year']=year

# %%
col = ['country',
 'iso_code',
 'date',
 'Year',
 'total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'daily_vaccinations_raw',
 'daily_vaccinations',
 'total_vaccinations_per_hundred',
 'people_vaccinated_per_hundred',
 'people_fully_vaccinated_per_hundred',
 'daily_vaccinations_per_million',
 'vaccines',
 'source_name',
 'source_website'
 ]

# %%
df.reindex(columns = col) #placing the year column right after date for out convenience
# Out:
#            country iso_code        date  Year  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22  2021                 0.0
# 1      Afghanistan      AFG  2021-02-23  2021                 NaN
# 2      Afghanistan      AFG  2021-02-24  2021                 NaN
# 3      Afghanistan      AFG  2021-02-25  2021                 NaN
# 4      Afghanistan      AFG  2021-02-26  2021                 NaN
# ...            ...      ...         ...   ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25  2022           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26  2022           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27  2022           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28  2022           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29  2022           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# ...

# %% [markdown]
# ## Adding month column in the dataset

# %%
month = []
for i in range(len(lst)):
    month.append(lst[i].split('-')[1])
df['Month'] = month

# %%
col = ['country',
 'iso_code',
 'date',
 'Year',
 'Month',
 'total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'daily_vaccinations_raw',
 'daily_vaccinations',
 'total_vaccinations_per_hundred',
 'people_vaccinated_per_hundred',
 'people_fully_vaccinated_per_hundred',
 'daily_vaccinations_per_million',
 'vaccines',
 'source_name',
 'source_website',
 ]
df.reindex(columns=col)  # Displaying the year and month columns beside date for out convenience
# Out:
#            country iso_code        date  Year Month  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22  2021    02                 0.0
# 1      Afghanistan      AFG  2021-02-23  2021    02                 NaN
# 2      Afghanistan      AFG  2021-02-24  2021    02                 NaN
# 3      Afghanistan      AFG  2021-02-25  2021    02                 NaN
# 4      Afghanistan      AFG  2021-02-26  2021    02                 NaN
# ...            ...      ...         ...   ...   ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25  2022    03           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26  2022    03           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27  2022    03           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28  2022    03           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29  2022    03           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# ...

# %% [markdown]
# ## Adding day column to the dataset

# %%
day = []
for i in range(len(lst)):
    day.append(lst[i].split('-')[2])
df['day'] = day

# %%
col = ['country',
 'iso_code',
 'date',
 'Year',
 'Month',
 'day',
 'total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'daily_vaccinations_raw',
 'daily_vaccinations',
 'total_vaccinations_per_hundred',
 'people_vaccinated_per_hundred',
 'people_fully_vaccinated_per_hundred',
 'daily_vaccinations_per_million',
 'vaccines',
 'source_name',
 'source_website',]
df.reindex(columns=col) # Displaying the year, month and day columns beside date column for out convenience
# Out:
#            country iso_code        date  Year Month day  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22  2021    02  22                 0.0
# 1      Afghanistan      AFG  2021-02-23  2021    02  23                 NaN
# 2      Afghanistan      AFG  2021-02-24  2021    02  24                 NaN
# 3      Afghanistan      AFG  2021-02-25  2021    02  25                 NaN
# 4      Afghanistan      AFG  2021-02-26  2021    02  26                 NaN
# ...            ...      ...         ...   ...   ...  ..                 ...
# 86507     Zimbabwe      ZWE  2022-03-25  2022    03  25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26  2022    03  26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27  2022    03  27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28  2022    03  28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29  2022    03  29           9039729.0
#
# ...
